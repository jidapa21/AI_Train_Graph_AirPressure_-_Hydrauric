# %% [markdown]
# <a href="https://colab.research.google.com/github/jidapa21/AI_Train_Graph_AirPressure_-_Hydrauric/blob/main/CiRA_DeepTrain_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Deep Train

# %%
import subprocess
ret = subprocess.call(['bash', '-c', 'wget -O  cira_deeptrain_colab.py https://raw.githubusercontent.com/CiRA-AMI/cira-colab-trainer/main/cira_deeptrain_colab.py'])

# %%
# %run cira_deeptrain_colab.py

# %% [markdown]
# Classif Train

# %%
import subprocess
ret = subprocess.call(['bash', '-c', 'wget -O  cira_classiftrain_colab.py https://raw.githubusercontent.com/CiRA-AMI/cira-colab-trainer/main/cira_classiftrain_colab.py'])

# %%
# %run cira_classiftrain_colab.py
